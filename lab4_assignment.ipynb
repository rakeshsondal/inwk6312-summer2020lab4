# %%
document=open("wordfile.txt")
print(document)
# Out:
# <_io.TextIOWrapper name='wordfile.txt' mode='r' encoding='cp1252'>

# %%
document=open("wordfile.txt")
single=document.readline()
print(single.strip())
# Out:
# ï»¿The Project Gutenberg eBook, An Australian Ramble, by J. Ewing Ritchie

# %%
import string
import math
document=open("wordfile.txt")
for i in document:
    i = i.translate(string.punctuation)
    n=i.strip()
    z=n.lower()
    p=z.strip()
    print(p)
# Out:
# ï»¿the project gutenberg ebook, an australian ramble, by j. ewing ritchie+
# +
# +
# this ebook is for the use of anyone anywhere in the united states and most+
# other parts of the world at no cost and with almost no restrictions +
# whatsoever.  you may copy it, give it away or re-use it under the terms of+
# the project gutenberg license included with this ebook or online at +
# www.gutenberg.org.  if you are not located in the united states, you'll have+
# to check the laws of the country where you are located before using this ebook.+
# +
# +
# +
# +
# title: an australian ramble+
# a summer in australia+
# +
# +
# author: j. ewing ritchie+
# +
# +
# +
# release date: may 9, 2020  [ebook #62069]+
# +
# language: english+
# +
# character set encoding: utf-8+
# +
# +
# ***start of the project gutenberg ebook an australian ramble***+
# +
# +
# transcribed from the 1890 t. fisher unwin edition by david price, email+
# ccx074@pglaf.org+
# +
# [picture: cover]+
# +
# +
# +
# +
# +
# ...

# %%
import string
import math
document=open("wordfile.txt",encoding="utf-8")
new_doc=[]
L={}
count=0
for i in document:
    for j in i.split():
        n=j.strip(string.punctuation).lower()
        new_doc.append(n)
        if n not in new_doc:
            count=1
            L.update
        else:
            count=count+1
            L.update

print(new_doc)
print(len(new_doc))
print("Number of times each word is used: ",L)
# Out:
# ['\ufeffthe', 'project', 'gutenberg', 'ebook', 'an', 'australian', 'ramble', 'by', 'j', 'ewing', 'ritchie', 'this', 'ebook', 'is', 'for', 'the', 'use', 'of', 'anyone', 'anywhere', 'in', 'the', 'united', 'states', 'and', 'most', 'other', 'parts', 'of', 'the', 'world', 'at', 'no', 'cost', 'and', 'with', 'almost', 'no', 'restrictions', 'whatsoever', 'you', 'may', 'copy', 'it', 'give', 'it', 'away', 'or', 're-use', 'it', 'under', 'the', 'terms', 'of', 'the', 'project', 'gutenberg', 'license', 'included', 'with', 'this', 'ebook', 'or', 'online', 'at', 'www.gutenberg.org', 'if', 'you', 'are', 'not', 'located', 'in', 'the', 'united', 'states', "you'll", 'have', 'to', 'check', 'the', 'laws', 'of', 'the', 'country', 'where', 'you', 'are', 'located', 'before', 'using', 'this', 'ebook', 'title', 'an', 'australian', 'ramble', 'a', 'summer', 'in', 'australia', 'author', 'j', 'ewing', 'ritchie', 'release', 'date', 'may', '9', '2020', 'ebook', '62069', 'language', 'english', 'character', 'set', 'en
# ...

# %%
import string
import math
list1=["import","string","module","and","math","module"]
list2=[]
document=open("wordfile.txt",encoding="utf-8")

for i in document:
    i.strip()
    words=i.split()
    for j in words:
        L=j.translate(string.punctuation).lower()
        list2.append(L)
    
    
set1=set(list1)
set2=set(list2)

print(set1.difference(set2))
# Out:
# {'string', 'import', 'math', 'module'}
